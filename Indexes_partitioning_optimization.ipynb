# %% [markdown]
# <a href="https://colab.research.google.com/github/nenuchepanu001/SqlQuery/blob/main/Indexes_partitioning_optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **User management**
#
#     create user <user_name> with password 'pwd123'
#
#     create role <role_name> with login password 'pwd123'
#
#     drop user <user_name>
#
#     drop role <role_name>
#
#
#     create user sarah with password 'krishna';
#
#     create role alex with login password 'abc123'
#
# **Grant and revoke priviliges**
#
#     --PRIVILEGES
#         SELECT
#         INSERT
#         UPDATE
#         DELETE
#         TRUNCATE
#         USAGE
#         ALL
#
#     GRANT SELECT ON CUSTOMER TO KRISHNA
#
#     GRANT SELECT
#     ON ALL TABLES IN SCHEMA <SCHEMA_NAME> TO KRISHNA WITH GRANT OPTION
#
#     REVOKE PRIVILEGE
#     ON DATABASE_OBJECT
#     FROM USER | ROLE | PUBLIC
#
#     REVOKE GRANT OPTION FOR PRIVILEGE
#     ON DATABASE_OBJECT
#     FROM USER | ROLE | PUBLIC
#     GRANTED BY USER | ROLE
#
#     GRANT USAGE ON SCHEMA NAME TO KRISHNA
#
#     GRANT SELECT,UPDATE ON CUSTOMER TO KRISHNA
#
#     GRANT ALL ON DATABASE GREENCYCLE TO KRISHNA
#
#     ALTER USER AMAR CREATEDB;
#
#     GRANT ANALYST TO KRISHNA;
#
#     REVOKE INSERT ON CUSTOMER FROM KRISHNA;
#
#
#     GRANT READ_ONLY TO KRISHNA;
#
# **INDEXES**
#
#     -- Indexes help to make data reads faster and slower data writes
#     --additional storage
#
#     # b-tree Index
#     -- multi level tree structure
#     -- breaks data down into pages or blocks
#     -- should be used for high cardinality
#     -- Not entire table (storage cost)
#
#     # bitmap index
#     --particularly good for dataware houses
#     --large amounts of data + low cardinality
#     -- very storage efficient
#     -- more optimized for read & few DML-operations
# *****************************************************
#     **Guidelines**
#     pass
#
# **create Indexes**
#
#     create index index_name on table_name [use:method] (column_name1,columnname2);
#
#     CREATE INDEX INDEX_RENTAL_ID_PAYMENT
#     ON PAYMENT (RENTAL_ID)
#
#     DROP INDEX INDEX_RENTAL_ID_PAYMENT
#
# **Execution plAN AND QUERY PERFORMANCE**
